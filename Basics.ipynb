# %% [markdown]
# In this project, we'll be working with Jupyter notebook, and analyzing data on gun deaths in the US.
#
# The dataset came from FiveThirtyEight, and can be found [here](https://github.com/fivethirtyeight/guns-data). The dataset is stored in the guns.csv file. It contains information on gun deaths in the US from 2012 to 2014. Each row in the dataset represents a single fatality. The columns contain demographic and other information about the victim.
#
# Key Findings:

# %%
import csv

f = open("guns.csv")
csvreader = csv.reader(f)
data = list(csvreader)
data[0:5]
# Out:
# [['',
#   'year',
#   'month',
#   'intent',
#   'police',
#   'sex',
#   'age',
#   'race',
#   'hispanic',
#   'place',
#   'education'],
#  ['1',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '4'],
#  ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'],
#  ['3',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]

# %%
headers = data[0]
headers
data = data[1:]
data
# Out:
# [['1',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '4'],
#  ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'],
#  ['3',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'],
#  ['5',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '31',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['6',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '17',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['7',
#   '2012',
#   '02',
#   'Undetermined',
#   '0',
#   'M',
#   '48',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['8',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '41',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['9',
#   '2012',
#   '02',
#   'Accidental',
#   '0',
#   'M',
#   '50',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['10', '2012', '02', 'Suicide', '0', 'M', 'NA', 'Black', '998', 'Home', '5'],
#  ['11', '2012', '02', 'Suicide', '0', 'M', '30', 'White', '100', 'Home', '3'],
#  ['12',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '21',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['13', '2012', '03', 'Suicide', '0', 'M', '43', 'White', '100', 'Home', '1'],
#  ['14',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['15', '2012', '03', 'Homicide', '0', 'M', '27', 'White', '100', 'Home', '2'],
#  ['16',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '27',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['17', '2012', '03', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '4'],
#  ['18',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '53',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['19',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '3'],
#  ['20', '2012', '04', 'Suicide', '0', 'M', '51', 'White', '100', 'Home', '2'],
#  ['21',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '65',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['22', '2012', '04', 'Suicide', '0', 'F', '52', 'White', '100', 'Home', '2'],
#  ['23', '2012', '04', 'Homicide', '0', 'F', '47', 'Black', '100', 'Home', '2'],
#  ['24', '2012', '04', 'Suicide', '0', 'M', '19', 'White', '100', 'Home', '3'],
#  ['25',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '51',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['26',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '41',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['27',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '22',
#   'Native American/Native Alaskan',
#   '100',
#   'Other specified',
#   '2'],
#  ['28',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '21',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['29', '2012', '04', 'Suicide', '0', 'M', '56', 'White', '100', 'Home', '2'],
#  ['30',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '43',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['31',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '38',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['32', '2012', '04', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '4'],
#  ['33',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '22',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '5'],
#  ['34', '2012', '05', 'Suicide', '0', 'M', '27', 'White', '100', 'Home', '2'],
#  ['35', '2012', '04', 'Homicide', '0', 'F', '25', 'White', '100', 'Home', '2'],
#  ['36',
#   '2012',
#   '04',
#   'Undetermined',
#   '0',
#   'M',
#   '26',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['37',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '23',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['38',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '48',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '5'],
#  ['39', '2012', '05', 'Suicide', '0', 'M', '43', 'White', '100', 'Home', '3'],
#  ['40', '2012', '05', 'Suicide', '0', 'M', '53', 'White', '100', 'Home', '3'],
#  ['41',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '31',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['42',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '26',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '5'],
#  ['43', '2012', '06', 'Suicide', '0', 'M', '87', 'White', '100', 'Home', '1'],
#  ['44',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '38',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['45',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '17',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['46', '2012', '06', 'Suicide', '0', 'M', '28', 'White', '100', 'Home', '3'],
#  ['47', '2012', '06', 'Suicide', '0', 'M', '39', 'White', '100', 'Home', '4'],
#  ['48', '2012', '07', 'Homicide', '0', 'M', '59', 'White', '100', 'Home', '2'],
#  ['49',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['50',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '38',
#   'Asian/Pacific Islander',
#   '100',
#   'Other specified',
#   '3'],
#  ['51', '2012', '07', 'Suicide', '0', 'M', '59', 'White', '100', 'Home', '2'],
#  ['52', '2012', '07', 'Suicide', '0', 'M', '26', 'White', '100', 'Home', '3'],
#  ['53',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '50',
#   'Native American/Native Alaskan',
#   '100',
#   'Street',
#   '1'],
#  ['54',
#   '2012',
#   '06',
#   'Undetermined',
#   '0',
#   'F',
#   '26',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['55', '2012', '07', 'Suicide', '0', 'M', '21', 'White', '100', 'Home', '2'],
#  ['56',
#   '2012',
#   '07',
#   'Suicide',
#   '0',
#   'M',
#   '61',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['57',
#   '2012',
#   '07',
#   'Accidental',
#   '0',
#   'M',
#   '12',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['58', '2012', '07', 'Homicide', '0', 'M', '40', 'White', '100', 'Home', '3'],
#  ['59', '2012', '07', 'Suicide', '0', 'M', '57', 'White', '100', 'Home', '2'],
#  ['60', '2012', '07', 'Homicide', '0', 'M', '19', 'Black', '100', 'Home', '2'],
#  ['61', '2012', '07', 'Suicide', '0', 'M', '22', 'White', '100', 'Home', '2'],
#  ['62', '2012', '08', 'Homicide', '1', 'M', '28', 'White', '100', 'NA', '2'],
#  ['63', '2012', '08', 'Suicide', '0', 'M', '20', 'White', '100', 'Home', '3'],
#  ['64', '2012', '07', 'Suicide', '0', 'F', '50', 'White', '100', 'Home', '2'],
#  ['65', '2012', '07', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '2'],
#  ['66',
#   '2012',
#   '08',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['67',
#   '2012',
#   '08',
#   'Suicide',
#   '0',
#   'F',
#   '23',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '3'],
#  ['68',
#   '2012',
#   '08',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['69',
#   '2012',
#   '08',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['70',
#   '2012',
#   '08',
#   'Suicide',
#   '0',
#   'M',
#   '26',
#   'Native American/Native Alaskan',
#   '100',
#   'Other specified',
#   '1'],
#  ['71', '2012', '08', 'Suicide', '0', 'F', '62', 'White', '100', 'Home', '4'],
#  ['72',
#   '2012',
#   '08',
#   'Accidental',
#   '0',
#   'M',
#   '71',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['73', '2012', '08', 'Suicide', '0', 'F', '44', 'White', '100', 'Home', '3'],
#  ['74',
#   '2012',
#   '09',
#   'Accidental',
#   '0',
#   'M',
#   '26',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['75',
#   '2012',
#   '09',
#   'Suicide',
#   '0',
#   'M',
#   '39',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['76',
#   '2012',
#   '09',
#   'Undetermined',
#   '0',
#   'M',
#   '26',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '3'],
#  ['77', '2012', '09', 'Suicide', '0', 'M', '57', 'White', '100', 'Home', '2'],
#  ['78',
#   '2012',
#   '09',
#   'Suicide',
#   '0',
#   'M',
#   '29',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '2'],
#  ['79', '2012', '09', 'Suicide', '0', 'M', '24', 'White', '100', 'Home', '2'],
#  ['80',
#   '2012',
#   '09',
#   'Homicide',
#   '0',
#   'F',
#   '30',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['81',
#   '2012',
#   '09',
#   'Suicide',
#   '0',
#   'F',
#   '50',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '4'],
#  ['82', '2012', '09', 'Suicide', '0', 'M', '61', 'White', '100', 'Home', '2'],
#  ['83',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'F',
#   '44',
#   'White',
#   '100',
#   'Other specified',
#   '5'],
#  ['84', '2012', '09', 'Homicide', '1', 'M', '34', 'White', '100', 'NA', '2'],
#  ['85',
#   '2012',
#   '09',
#   'Suicide',
#   '0',
#   'M',
#   '28',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['86',
#   '2012',
#   '09',
#   'Homicide',
#   '0',
#   'M',
#   '9',
#   'Native American/Native Alaskan',
#   '100',
#   'Other specified',
#   '1'],
#  ['87', '2012', '09', 'Suicide', '0', 'M', '77', 'White', '100', 'Home', '4'],
#  ['88',
#   '2012',
#   '09',
#   'Suicide',
#   '0',
#   'M',
#   '17',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['89',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['90',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'M',
#   '22',
#   'Native American/Native Alaskan',
#   '100',
#   'Other specified',
#   '1'],
#  ['91',
#   '2012',
#   '09',
#   'Undetermined',
#   '0',
#   'F',
#   '22',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['92', '2012', '10', 'Suicide', '0', 'M', '18', 'White', '100', 'Home', '1'],
#  ['93',
#   '2012',
#   '10',
#   'Homicide',
#   '1',
#   'M',
#   '24',
#   'Native American/Native Alaskan',
#   '100',
#   'NA',
#   '1'],
#  ['94',
#   '2012',
#   '09',
#   'Accidental',
#   '0',
#   'F',
#   '19',
#   'Hispanic',
#   '281',
#   'Other unspecified',
#   '2'],
#  ['95',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'M',
#   '61',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['96', '2012', '10', 'Suicide', '0', 'M', '71', 'White', '100', 'Home', '2'],
#  ['97', '2012', '10', 'Suicide', '0', 'M', '36', 'White', '100', 'Home', '1'],
#  ['98',
#   '2012',
#   '10',
#   'Homicide',
#   '0',
#   'M',
#   '27',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['99',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'M',
#   '49',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['100',
#   '2012',
#   '09',
#   'Undetermined',
#   '0',
#   'M',
#   '19',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['101',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '13',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['102', '2012', '10', 'Suicide', '0', 'M', '20', 'White', '100', 'Home', '3'],
#  ['103',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '30',
#   'Hispanic',
#   '211',
#   'Home',
#   '3'],
#  ['104',
#   '2012',
#   '10',
#   'Homicide',
#   '0',
#   'M',
#   '61',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['105', '2012', '11', 'Suicide', '0', 'F', '51', 'White', '100', 'Home', '1'],
#  ['106',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Other specified',
#   '3'],
#  ['107',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '20',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['108', '2012', '11', 'Suicide', '0', 'M', '50', 'White', '100', 'Home', '2'],
#  ['109',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'F',
#   '48',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '3'],
#  ['110',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '21',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['111',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '43',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['112',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '21',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['113', '2012', '12', 'Suicide', '0', 'M', '51', 'White', '100', 'Home', '2'],
#  ['114', '2012', '11', 'Suicide', '0', 'M', '90', 'White', '100', 'Home', '1'],
#  ['115',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'F',
#   '33',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['116', '2012', '12', 'Suicide', '0', 'M', '43', 'Black', '100', 'Home', '3'],
#  ['117', '2012', '11', 'Suicide', '0', 'M', '48', 'White', '998', 'Home', '5'],
#  ['118',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '24',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '1'],
#  ['119',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '63',
#   'Asian/Pacific Islander',
#   '100',
#   'Other specified',
#   '3'],
#  ['120',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '46',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['121', '2012', '12', 'Suicide', '0', 'M', '32', 'White', '100', 'Home', '1'],
#  ['122',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '84',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['123',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'M',
#   '68',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['124', '2012', '12', 'Suicide', '0', 'M', '13', 'Black', '100', 'Home', '1'],
#  ['125', '2012', '12', 'Suicide', '0', 'F', '89', 'White', '100', 'Home', '4'],
#  ['126',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['127',
#   '2012',
#   '12',
#   'Undetermined',
#   '0',
#   'M',
#   '28',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['128',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '48',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['129',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '39',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '2'],
#  ['130', '2012', '12', 'Suicide', '0', 'M', '43', 'White', '100', 'Home', '3'],
#  ['131',
#   '2012',
#   '12',
#   'Accidental',
#   '0',
#   'F',
#   '31',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['132', '2012', '12', 'Suicide', '0', 'M', '46', 'White', '100', 'Home', '2'],
#  ['133', '2012', '12', 'Suicide', '0', 'M', '33', 'White', '100', 'Home', '2'],
#  ['134',
#   '2012',
#   '12',
#   'Undetermined',
#   '0',
#   'F',
#   '31',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['135', '2012', '01', 'Suicide', '0', 'F', '59', 'White', '100', 'Home', '2'],
#  ['136',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'F',
#   '30',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['137',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '58',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['138', '2012', '01', 'Suicide', '0', 'M', '78', 'White', '100', 'Home', '4'],
#  ['139',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['140',
#   '2012',
#   '01',
#   'Accidental',
#   '0',
#   'M',
#   '61',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['141',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '55',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['142', '2012', '01', 'Suicide', '0', 'M', '66', 'White', '100', 'Home', '2'],
#  ['143',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '52',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['144', '2012', '01', 'Suicide', '0', 'M', '63', 'White', '100', 'Home', '3'],
#  ['145', '2012', '01', 'Suicide', '0', 'M', '40', 'White', '100', 'Home', '4'],
#  ['146',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['147',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '57',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['148',
#   '2012',
#   '01',
#   'Undetermined',
#   '0',
#   'M',
#   '81',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['149',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '63',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['150',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '54',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['151',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '46',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['152',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '52',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['153', '2012', '01', 'Suicide', '0', 'M', '59', 'White', '100', 'Home', '4'],
#  ['154',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '31',
#   'Black',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['155', '2012', '01', 'Suicide', '0', 'M', '64', 'Black', '100', 'Home', '2'],
#  ['156',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'F',
#   '36',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['157',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '40',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['158',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '45',
#   'Hispanic',
#   '211',
#   'Home',
#   '1'],
#  ['159',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '47',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['160',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'F',
#   '53',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['161',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '55',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['162',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '26',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['163',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['164',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['165',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '68',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['166',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '49',
#   'Black',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['167',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'F',
#   '48',
#   'Black',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['168',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '68',
#   'Black',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['169',
#   '2012',
#   '01',
#   'Undetermined',
#   '0',
#   'M',
#   '45',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['170',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '47',
#   'White',
#   '100',
#   'Home',
#   '4'],
#  ['171', '2012', '01', 'Suicide', '0', 'M', '37', 'Black', '100', 'Home', '2'],
#  ['172', '2012', '02', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '2'],
#  ['173',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '62',
#   'White',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['174',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['175', '2012', '01', 'Suicide', '0', 'F', '53', 'White', '100', 'Home', '3'],
#  ['176',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '36',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['177',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'F',
#   '41',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['178',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '47',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['179', '2012', '01', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '3'],
#  ['180',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '30',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['181',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '43',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['182', '2012', '01', 'Suicide', '0', 'M', '41', 'Black', '100', 'Home', '2'],
#  ['183',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['184',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '39',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['185',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '35',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['186',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '35',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['187',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '30',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['188',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['189',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['190',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '19',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['191',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['192',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Hispanic',
#   '261',
#   'Home',
#   '1'],
#  ['193',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '49',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['194', '2012', '02', 'Suicide', '0', 'M', '50', 'White', '100', 'Home', '2'],
#  ['195',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '44',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['196',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '46',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['197',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '46',
#   'White',
#   '100',
#   'Farm',
#   '2'],
#  ['198',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['199',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '42',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['200',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '42',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['201',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '34',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['202',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '50',
#   'White',
#   '100',
#   'Other specified',
#   '1'],
#  ['203', '2012', '01', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '2'],
#  ['204',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['205',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '47',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['206',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '36',
#   'Black',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['207',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['208', '2012', '02', 'Suicide', '0', 'M', '22', 'White', '100', 'Home', '1'],
#  ['209',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'F',
#   '20',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['210',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '58',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['211', '2012', '01', 'Suicide', '0', 'M', '67', 'Black', '100', 'Home', '4'],
#  ['212',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'F',
#   '18',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['213',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'F',
#   '32',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['214', '2012', '02', 'Suicide', '0', 'M', '69', 'White', '100', 'Home', '2'],
#  ['215',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '84',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['216',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'F',
#   '31',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['217',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '42',
#   'Black',
#   '100',
#   'Industrial/construction',
#   '1'],
#  ['218', '2012', '02', 'Suicide', '0', 'M', '20', 'White', '100', 'Home', '3'],
#  ['219', '2012', '02', 'Suicide', '0', 'M', '48', 'White', '100', 'Home', '4'],
#  ['220', '2012', '02', 'Suicide', '0', 'M', '54', 'White', '100', 'Home', '2'],
#  ['221',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'F',
#   '37',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['222', '2012', '01', 'Suicide', '0', 'M', '56', 'White', '100', 'Home', '2'],
#  ['223',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '34',
#   'Black',
#   '100',
#   'Trade/service area',
#   '3'],
#  ['224',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'F',
#   '20',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['225', '2012', '02', 'Suicide', '0', 'M', '72', 'Black', '100', 'Home', '1'],
#  ['226', '2012', '01', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '2'],
#  ['227', '2012', '02', 'Suicide', '0', 'M', '35', 'White', '100', 'Home', '3'],
#  ['228',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'F',
#   '17',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['229', '2012', '03', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '2'],
#  ['230',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '42',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['231',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '47',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['232', '2012', '02', 'Suicide', '0', 'M', '82', 'White', '100', 'Home', '3'],
#  ['233',
#   '2012',
#   '02',
#   'Accidental',
#   '0',
#   'M',
#   '25',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['234',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'F',
#   '28',
#   'White',
#   '100',
#   'Farm',
#   '2'],
#  ['235', '2012', '02', 'Suicide', '0', 'M', '38', 'White', '100', 'Home', '3'],
#  ['236',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '49',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['237', '2012', '03', 'Suicide', '0', 'M', '36', 'Black', '100', 'Home', '4'],
#  ['238',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '29',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['239',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '75',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['240', '2012', '03', 'Suicide', '0', 'M', '57', 'White', '100', 'Home', '1'],
#  ['241',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '49',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['242',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '73',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['243', '2012', '02', 'Suicide', '0', 'M', '53', 'White', '100', 'Home', '1'],
#  ['244',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'F',
#   '24',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['245',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '45',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['246', '2012', '03', 'Suicide', '0', 'M', '52', 'White', '100', 'Home', '3'],
#  ['247', '2012', '03', 'Suicide', '0', 'M', '81', 'White', '100', 'Home', '2'],
#  ['248',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'Black',
#   '100',
#   'School/instiution',
#   '1'],
#  ['249',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '32',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['250',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '46',
#   'Black',
#   '100',
#   'Home',
#   '4'],
#  ['251', '2012', '02', 'Suicide', '0', 'F', '65', 'White', '100', 'Home', '2'],
#  ['252',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '18',
#   'Black',
#   '100',
#   'School/instiution',
#   '2'],
#  ['253',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '15',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['254', '2012', '03', 'Suicide', '0', 'M', '49', 'White', '100', 'Home', '4'],
#  ['255',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '51',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['256',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '29',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['257',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '62',
#   'White',
#   '100',
#   'Trade/service area',
#   '4'],
#  ['258',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '33',
#   'Hispanic',
#   '211',
#   'Home',
#   '2'],
#  ['259',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '78',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['260', '2012', '02', 'Suicide', '0', 'M', '58', 'White', '100', 'Home', '3'],
#  ['261',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['262',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '82',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['263',
#   '2012',
#   '03',
#   'Undetermined',
#   '0',
#   'M',
#   '23',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['264',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '83',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['265', '2012', '02', 'Suicide', '0', 'M', '50', 'Black', '100', 'Home', '1'],
#  ['266', '2012', '03', 'Suicide', '0', 'M', '13', 'White', '100', 'Home', '1'],
#  ['267',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '17',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['268', '2012', '03', 'Suicide', '0', 'M', '30', 'White', '100', 'Home', '2'],
#  ['269',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '63',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['270',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '64',
#   'White',
#   '100',
#   'Street',
#   '3'],
#  ['271',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '40',
#   'White',
#   '100',
#   'Trade/service area',
#   '4'],
#  ['272',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '42',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['273',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '32',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['274',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['275', '2012', '03', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '2'],
#  ['276',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '49',
#   'White',
#   '100',
#   'Street',
#   '1'],
#  ['277',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '37',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['278', '2012', '02', 'Suicide', '0', 'M', '83', 'White', '100', 'Home', '3'],
#  ['279', '2012', '03', 'Suicide', '0', 'F', '54', 'White', '100', 'Home', '2'],
#  ['280', '2012', '04', 'Suicide', '0', 'M', '72', 'White', '100', 'Home', '4'],
#  ['281', '2012', '03', 'Suicide', '0', 'M', '74', 'White', '100', 'Home', '3'],
#  ['282',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '54',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['283', '2012', '03', 'Suicide', '0', 'M', '34', 'Black', '100', 'Home', '2'],
#  ['284', '2012', '04', 'Suicide', '0', 'M', '74', 'White', '100', 'Home', '2'],
#  ['285',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['286', '2012', '03', 'Suicide', '0', 'M', '46', 'White', '100', 'Home', '4'],
#  ['287', '2012', '03', 'Suicide', '0', 'M', '48', 'Black', '100', 'Home', '1'],
#  ['288', '2012', '03', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '1'],
#  ['289',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '48',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['290',
#   '2012',
#   '03',
#   'Accidental',
#   '0',
#   'M',
#   '17',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['291',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '26',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['292',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '19',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['293',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '40',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['294',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '42',
#   'Black',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['295',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '48',
#   'Black',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['296',
#   '2012',
#   '02',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'White',
#   '100',
#   'Street',
#   '1'],
#  ['297',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['298',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '30',
#   'Black',
#   '100',
#   'Street',
#   '3'],
#  ['299',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '23',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['300', '2012', '04', 'Suicide', '0', 'M', '23', 'White', '100', 'Home', '2'],
#  ['301', '2012', '04', 'Suicide', '0', 'M', '49', 'White', '100', 'Home', '4'],
#  ['302',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '30',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['303', '2012', '04', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '2'],
#  ['304',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '47',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['305',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'F',
#   '68',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['306',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '68',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['307',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '27',
#   'White',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['308', '2012', '03', 'Suicide', '0', 'M', '29', 'Black', '100', 'Home', '3'],
#  ['309',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'F',
#   '31',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['310', '2012', '04', 'Suicide', '0', 'F', '40', 'White', '100', 'Home', '3'],
#  ['311', '2012', '04', 'Suicide', '0', 'M', '41', 'White', '100', 'Home', '2'],
#  ['312',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['313',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '48',
#   'White',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['314',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '19',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['315', '2012', '03', 'Suicide', '0', 'M', '52', 'White', '100', 'Home', '2'],
#  ['316', '2012', '04', 'Suicide', '0', 'M', '75', 'White', '100', 'Home', '1'],
#  ['317',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '21',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['318',
#   '2012',
#   '04',
#   'Accidental',
#   '0',
#   'M',
#   '24',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['319', '2012', '04', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '2'],
#  ['320', '2012', '04', 'Suicide', '0', 'F', '37', 'White', '100', 'Home', '3'],
#  ['321',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '43',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['322', '2012', '04', 'Suicide', '0', 'M', '53', 'White', '100', 'Home', '2'],
#  ['323', '2012', '03', 'Suicide', '0', 'M', '43', 'Black', '100', 'Home', '4'],
#  ['324',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'F',
#   '43',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['325',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '28',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['326',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '19',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['327', '2012', '03', 'Suicide', '0', 'M', '54', 'White', '100', 'Home', '4'],
#  ['328', '2012', '04', 'Suicide', '0', 'M', '86', 'White', '100', 'Home', '1'],
#  ['329', '2012', '04', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '1'],
#  ['330',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '17',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['331', '2012', '04', 'Suicide', '0', 'F', '46', 'White', '100', 'Home', '3'],
#  ['332', '2012', '04', 'Suicide', '0', 'M', '54', 'White', '100', 'Home', '1'],
#  ['333', '2012', '04', 'Suicide', '0', 'M', '52', 'White', '100', 'Home', '3'],
#  ['334',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'F',
#   '44',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['335',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'F',
#   '40',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['336',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'F',
#   '24',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['337',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '22',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['338', '2012', '04', 'Suicide', '0', 'F', '69', 'White', '100', 'Home', '2'],
#  ['339',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '47',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['340', '2012', '04', 'Suicide', '0', 'F', '32', 'White', '100', 'Home', '1'],
#  ['341', '2012', '04', 'Suicide', '0', 'M', '21', 'White', '100', 'Home', '2'],
#  ['342',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '26',
#   'Black',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['343', '2012', '04', 'Suicide', '0', 'M', '63', 'White', '100', 'Home', '2'],
#  ['344',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['345', '2012', '04', 'Suicide', '0', 'M', '72', 'White', '100', 'Home', '1'],
#  ['346', '2012', '03', 'Suicide', '0', 'M', '57', 'Black', '100', 'Home', '4'],
#  ['347', '2012', '04', 'Suicide', '0', 'M', '52', 'White', '100', 'Home', '3'],
#  ['348', '2012', '04', 'Suicide', '0', 'M', '69', 'White', '100', 'Home', '4'],
#  ['349', '2012', '04', 'Suicide', '0', 'M', '50', 'White', '100', 'Home', '3'],
#  ['350', '2012', '04', 'Suicide', '0', 'M', '40', 'White', '100', 'Home', '2'],
#  ['351',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '36',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['352',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '40',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['353',
#   '2012',
#   '03',
#   'Suicide',
#   '0',
#   'M',
#   '28',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['354',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['355',
#   '2012',
#   '04',
#   'Accidental',
#   '0',
#   'M',
#   '53',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['356', '2012', '04', 'Suicide', '0', 'M', '16', 'White', '100', 'Home', '1'],
#  ['357',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'F',
#   '29',
#   'Black',
#   '100',
#   'Street',
#   '3'],
#  ['358',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'F',
#   '48',
#   'White',
#   '100',
#   'Street',
#   '4'],
#  ['359', '2012', '04', 'Suicide', '0', 'M', '32', 'Black', '100', 'Home', '2'],
#  ['360',
#   '2012',
#   '04',
#   'Undetermined',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['361',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['362',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '39',
#   'White',
#   '100',
#   'Street',
#   '1'],
#  ['363', '2012', '04', 'Suicide', '0', 'M', '19', 'White', '100', 'Home', '2'],
#  ['364',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '44',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['365',
#   '2012',
#   '05',
#   'Accidental',
#   '0',
#   'M',
#   '63',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['366',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '17',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['367', '2012', '05', 'Suicide', '0', 'M', '43', 'White', '100', 'Home', '3'],
#  ['368',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '47',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['369',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '29',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['370', '2012', '05', 'Suicide', '0', 'M', '75', 'Black', '100', 'Home', '2'],
#  ['371',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['372',
#   '2012',
#   '03',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['373', '2012', '04', 'Suicide', '0', 'M', '18', 'White', '100', 'Home', '1'],
#  ['374', '2012', '05', 'Suicide', '0', 'M', '84', 'White', '100', 'Home', '2'],
#  ['375', '2012', '05', 'Suicide', '0', 'M', '29', 'White', '100', 'Home', '2'],
#  ['376',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['377', '2012', '05', 'Suicide', '0', 'M', '18', 'White', '100', 'Home', '1'],
#  ['378',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'F',
#   '30',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['379', '2012', '05', 'Suicide', '0', 'M', '50', 'White', '100', 'Home', '2'],
#  ['380',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '36',
#   'White',
#   '100',
#   'Street',
#   '3'],
#  ['381', '2012', '05', 'Suicide', '0', 'M', '88', 'White', '100', 'Home', '2'],
#  ['382', '2012', '05', 'Suicide', '0', 'M', '29', 'White', '100', 'Home', '1'],
#  ['383', '2012', '05', 'Suicide', '0', 'M', '87', 'White', '100', 'Home', '4'],
#  ['384',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '13',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['385',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'F',
#   '17',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['386', '2012', '05', 'Suicide', '0', 'M', '40', 'White', '100', 'Home', '3'],
#  ['387',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'F',
#   '20',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '3'],
#  ['388',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '58',
#   'White',
#   '100',
#   'Street',
#   '4'],
#  ['389', '2012', '05', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '3'],
#  ['390',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['391', '2012', '05', 'Suicide', '0', 'M', '26', 'White', '100', 'Home', '2'],
#  ['392',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'F',
#   '44',
#   'White',
#   '100',
#   'Street',
#   '1'],
#  ['393',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '44',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['394',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '74',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['395',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '82',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['396',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '27',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['397',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '61',
#   'White',
#   '100',
#   'Sports',
#   '4'],
#  ['398', '2012', '05', 'Suicide', '0', 'M', '44', 'White', '100', 'Home', '4'],
#  ['399', '2012', '05', 'Suicide', '0', 'M', '34', 'White', '100', 'Home', '2'],
#  ['400',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '58',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['401', '2012', '05', 'Suicide', '0', 'M', '74', 'White', '100', 'Home', '2'],
#  ['402', '2012', '05', 'Suicide', '0', 'M', '67', 'White', '100', 'Home', '2'],
#  ['403', '2012', '05', 'Suicide', '0', 'M', '73', 'White', '100', 'Home', '2'],
#  ['404', '2012', '05', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '2'],
#  ['405', '2012', '04', 'Suicide', '0', 'F', '55', 'White', '100', 'Home', '2'],
#  ['406', '2012', '05', 'Suicide', '0', 'M', '22', 'Black', '100', 'Home', '1'],
#  ['407',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['408', '2012', '06', 'Suicide', '0', 'M', '40', 'White', '100', 'Home', '3'],
#  ['409', '2012', '06', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '2'],
#  ['410', '2012', '05', 'Suicide', '0', 'M', '52', 'White', '100', 'Home', '1'],
#  ['411',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '47',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['412',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '32',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['413',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['414',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'M',
#   '23',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['415', '2012', '06', 'Suicide', '0', 'M', '17', 'Black', '100', 'Home', '1'],
#  ['416', '2012', '05', 'Suicide', '0', 'F', '69', 'White', '100', 'Home', '2'],
#  ['417',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['418',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '45',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['419',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '53',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['420', '2012', '05', 'Suicide', '0', 'M', '78', 'White', '100', 'Home', '3'],
#  ['421', '2012', '06', 'Suicide', '0', 'M', '68', 'White', '100', 'Home', '4'],
#  ['422',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['423', '2012', '06', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '2'],
#  ['424',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '30',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['425',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '71',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['426', '2012', '05', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'],
#  ['427', '2012', '06', 'Suicide', '0', 'M', '45', 'White', '100', 'Home', '2'],
#  ['428', '2012', '05', 'Suicide', '0', 'M', '60', 'White', '100', 'Home', '3'],
#  ['429',
#   '2012',
#   '05',
#   'Accidental',
#   '0',
#   'F',
#   '20',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['430', '2012', '05', 'Suicide', '0', 'M', '60', 'White', '100', 'Home', '2'],
#  ['431', '2012', '05', 'Suicide', '0', 'F', '30', 'White', '100', 'Home', '3'],
#  ['432',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '13',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['433',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '3',
#   'White',
#   '100',
#   'Other unspecified',
#   'NA'],
#  ['434',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Black',
#   '100',
#   'Street',
#   '3'],
#  ['435', '2012', '05', 'Suicide', '0', 'M', '26', 'Black', '100', 'Home', '2'],
#  ['436', '2012', '05', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '2'],
#  ['437', '2012', '05', 'Suicide', '0', 'M', '48', 'White', '100', 'Home', '1'],
#  ['438', '2012', '06', 'Suicide', '0', 'F', '39', 'White', '100', 'Home', '2'],
#  ['439',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '32',
#   'Black',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['440', '2012', '06', 'Suicide', '0', 'M', '63', 'White', '100', 'Home', '1'],
#  ['441',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'F',
#   '29',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['442',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '42',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['443',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['444',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'F',
#   '18',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['445', '2012', '06', 'Suicide', '0', 'M', '55', 'White', '100', 'Home', '1'],
#  ['446',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['447', '2012', '06', 'Suicide', '0', 'M', '82', 'White', '100', 'Home', '4'],
#  ['448',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '27',
#   'Black',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['449',
#   '2012',
#   '04',
#   'Suicide',
#   '0',
#   'F',
#   '36',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['450', '2012', '06', 'Suicide', '0', 'M', '49', 'White', '100', 'Home', '4'],
#  ['451', '2012', '06', 'Suicide', '0', 'M', '43', 'White', '100', 'Home', '2'],
#  ['452',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '50',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['453', '2012', '06', 'Suicide', '0', 'M', '80', 'White', '100', 'Home', '4'],
#  ['454', '2012', '06', 'Suicide', '0', 'M', '63', 'White', '100', 'Home', '3'],
#  ['455',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'F',
#   '28',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['456',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '35',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['457',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'White',
#   '100',
#   'Street',
#   '2'],
#  ['458', '2012', '05', 'Suicide', '0', 'F', '45', 'White', '100', 'Home', '1'],
#  ['459',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['460',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'F',
#   '65',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['461',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '17',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['462', '2012', '06', 'Suicide', '0', 'F', '48', 'White', '100', 'Home', '4'],
#  ['463',
#   '2012',
#   '05',
#   'Accidental',
#   '0',
#   'F',
#   '25',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['464', '2012', '06', 'Suicide', '0', 'M', '58', 'White', '100', 'Home', '2'],
#  ['465', '2012', '06', 'Suicide', '0', 'M', '65', 'White', '100', 'Home', '3'],
#  ['466',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '20',
#   'White',
#   '100',
#   'Street',
#   '2'],
#  ['467', '2012', '06', 'Suicide', '0', 'M', '60', 'White', '100', 'Home', '3'],
#  ['468', '2012', '06', 'Suicide', '0', 'M', '66', 'White', '100', 'Home', '2'],
#  ['469', '2012', '06', 'Suicide', '0', 'M', '75', 'White', '100', 'Home', '1'],
#  ['470',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '58',
#   'Black',
#   '100',
#   'Street',
#   '3'],
#  ['471',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'F',
#   '54',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['472', '2012', '05', 'Suicide', '0', 'M', '56', 'White', '100', 'Home', '3'],
#  ['473',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['474',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['475', '2012', '06', 'Suicide', '0', 'M', '69', 'White', '100', 'Home', '4'],
#  ['476',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '34',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['477',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['478', '2012', '06', 'Suicide', '0', 'M', '43', 'White', '100', 'Home', '2'],
#  ['479', '2012', '06', 'Suicide', '0', 'M', '19', 'White', '100', 'Home', '2'],
#  ['480',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '38',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['481', '2012', '06', 'Suicide', '0', 'F', '61', 'White', '100', 'Home', '3'],
#  ['482', '2012', '07', 'Suicide', '0', 'M', '65', 'White', '100', 'Home', '2'],
#  ['483', '2012', '06', 'Suicide', '0', 'M', '72', 'White', '100', 'Home', '2'],
#  ['484',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['485',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['486',
#   '2012',
#   '06',
#   'Suicide',
#   '0',
#   'M',
#   '39',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['487',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '59',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['488', '2012', '07', 'Suicide', '0', 'M', '29', 'White', '100', 'Home', '3'],
#  ['489',
#   '2012',
#   '05',
#   'Suicide',
#   '0',
#   'M',
# ...
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['839',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['840',
#   '2012',
#   '10',
#   'Homicide',
#   '0',
#   'M',
#   '35',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['841',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'Black',
#   '100',
#   'Industrial/construction',
#   '3'],
#  ['842',
#   '2012',
#   '10',
#   'Homicide',
#   '0',
#   'M',
#   '30',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['843', '2012', '11', 'Suicide', '0', 'F', '47', 'White', '100', 'Farm', '2'],
#  ['844', '2012', '11', 'Suicide', '0', 'M', '45', 'White', '100', 'Home', '1'],
#  ['845',
#   '2012',
#   '10',
#   'Accidental',
#   '0',
#   'M',
#   '53',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['846', '2012', '11', 'Suicide', '0', 'M', '22', 'Black', '100', 'Home', '3'],
#  ['847', '2012', '11', 'Suicide', '0', 'M', '50', 'White', '100', 'Home', '2'],
#  ['848', '2012', '11', 'Suicide', '0', 'M', '95', 'White', '100', 'Home', '2'],
#  ['849',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '51',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['850',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'F',
#   '43',
#   'White',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['851',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['852', '2012', '11', 'Suicide', '0', 'F', '36', 'Black', '100', 'Home', '4'],
#  ['853', '2012', '11', 'Suicide', '0', 'M', '73', 'White', '100', 'Home', '3'],
#  ['854',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['855', '2012', '12', 'Suicide', '0', 'M', '20', 'White', '100', 'Home', '2'],
#  ['856',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '27',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['857',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['858',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['859',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '19',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['860', '2012', '11', 'Suicide', '0', 'M', '71', 'White', '100', 'Home', '2'],
#  ['861',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['862',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'White',
#   '100',
#   'Street',
#   '3'],
#  ['863',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '24',
#   'Hispanic',
#   '211',
#   'Other unspecified',
#   '1'],
#  ['864',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '43',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['865', '2012', '11', 'Suicide', '0', 'M', '61', 'White', '100', 'Home', '3'],
#  ['866',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '49',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '4'],
#  ['867', '2012', '10', 'Suicide', '0', 'F', '43', 'White', '100', 'Home', '2'],
#  ['868', '2012', '11', 'Suicide', '0', 'M', '50', 'White', '100', 'Home', '3'],
#  ['869',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '44',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['870',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '61',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['871',
#   '2012',
#   '10',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['872',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'F',
#   '96',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['873',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '42',
#   'White',
#   '100',
#   'Farm',
#   '2'],
#  ['874',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '3'],
#  ['875',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['876',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['877',
#   '2012',
#   '09',
#   'Suicide',
#   '0',
#   'M',
#   '17',
#   'White',
#   '100',
#   'Street',
#   '2'],
#  ['878', '2012', '12', 'Suicide', '0', 'M', '59', 'White', '100', 'Home', '1'],
#  ['879', '2012', '12', 'Suicide', '0', 'M', '41', 'White', '100', 'Home', '3'],
#  ['880',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['881',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '40',
#   'White',
#   '100',
#   'Street',
#   '2'],
#  ['882', '2012', '12', 'Suicide', '0', 'M', '57', 'White', '100', 'Home', '1'],
#  ['883', '2012', '11', 'Suicide', '0', 'M', '44', 'Black', '100', 'Home', '3'],
#  ['884', '2012', '12', 'Suicide', '0', 'M', '77', 'White', '100', 'Home', '2'],
#  ['885',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['886',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '68',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['887',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'F',
#   '29',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['888', '2012', '12', 'Suicide', '0', 'M', '68', 'White', '100', 'Home', '4'],
#  ['889',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['890',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['891',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '48',
#   'White',
#   '100',
#   'Street',
#   '2'],
#  ['892',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['893',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['894',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Black',
#   '100',
#   'Other unspecified',
#   '4'],
#  ['895', '2012', '12', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '2'],
#  ['896',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['897',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['898', '2012', '12', 'Suicide', '0', 'M', '41', 'White', '100', 'Home', '1'],
#  ['899', '2012', '12', 'Suicide', '0', 'M', '26', 'White', '100', 'Home', '2'],
#  ['900',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['901',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'M',
#   '50',
#   'White',
#   '100',
#   'Trade/service area',
#   '3'],
#  ['902',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '37',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['903',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '38',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['904', '2012', '12', 'Suicide', '0', 'M', '66', 'White', '100', 'Home', '2'],
#  ['905',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '63',
#   'Black',
#   '100',
#   'Home',
#   '4'],
#  ['906',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '18',
#   'Hispanic',
#   '211',
#   'Other unspecified',
#   '1'],
#  ['907',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '36',
#   'Hispanic',
#   '211',
#   'Other unspecified',
#   '1'],
#  ['908',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '23',
#   'Hispanic',
#   '211',
#   'Other unspecified',
#   '1'],
#  ['909',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '38',
#   'White',
#   '100',
#   'School/instiution',
#   '3'],
#  ['910',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['911', '2012', '12', 'Suicide', '0', 'M', '41', 'White', '100', 'Home', '2'],
#  ['912',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '26',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['913', '2012', '12', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '3'],
#  ['914',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '21',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['915',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['916',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'F',
#   '70',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['917',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '43',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['918',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '18',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['919',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '20',
#   'White',
#   '100',
#   'Home',
#   '3'],
#  ['920',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['921', '2012', '12', 'Suicide', '0', 'M', '36', 'White', '100', 'Home', '2'],
#  ['922',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '34',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['923', '2012', '12', 'Suicide', '0', 'M', '73', 'White', '100', 'Home', '2'],
#  ['924', '2012', '12', 'Suicide', '0', 'M', '42', 'White', '100', 'Home', '2'],
#  ['925', '2012', '12', 'Suicide', '0', 'M', '54', 'White', '100', 'Home', '2'],
#  ['926', '2012', '12', 'Suicide', '0', 'F', '66', 'White', '100', 'Home', '2'],
#  ['927',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'F',
#   '54',
#   'White',
#   '100',
#   'Other unspecified',
#   '3'],
#  ['928',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '24',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['929',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '33',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['930', '2012', '12', 'Suicide', '0', 'F', '52', 'White', '100', 'Home', '3'],
#  ['931',
#   '2012',
#   '12',
#   'Accidental',
#   '0',
#   'M',
#   '33',
#   'Hispanic',
#   '211',
#   'Other unspecified',
#   '1'],
#  ['932', '2012', '12', 'Suicide', '0', 'M', '25', 'White', '100', 'Home', '3'],
#  ['933',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '19',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['934',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'F',
#   '20',
#   'Black',
#   '100',
#   'School/instiution',
#   '2'],
#  ['935', '2012', '12', 'Suicide', '0', 'M', '73', 'White', '100', 'Home', '3'],
#  ['936',
#   '2012',
#   '12',
#   'Undetermined',
#   '0',
#   'M',
#   '58',
#   'White',
#   '100',
#   'Other unspecified',
#   '1'],
#  ['937', '2012', '12', 'Suicide', '0', 'F', '72', 'White', '100', 'Home', '2'],
#  ['938',
#   '2012',
#   '11',
#   'Homicide',
#   '0',
#   'M',
#   '30',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['939',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '19',
#   'Black',
#   '100',
#   'School/instiution',
#   '2'],
#  ['940', '2012', '11', 'Suicide', '0', 'M', '32', 'Black', '100', 'Home', '1'],
#  ['941', '2012', '12', 'Suicide', '0', 'M', '68', 'White', '100', 'Home', '3'],
#  ['942',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Street',
#   '1'],
#  ['943',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '47',
#   'Black',
#   '100',
#   'Other specified',
#   '1'],
#  ['944',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['945',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'White',
#   '100',
#   'Industrial/construction',
#   '2'],
#  ['946',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '42',
#   'Black',
#   '100',
#   'Street',
#   '3'],
#  ['947',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '35',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['948',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '18',
#   'Black',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['949',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '65',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['950',
#   '2012',
#   '08',
#   'Homicide',
#   '0',
#   'M',
#   '25',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['951',
#   '2012',
#   '06',
#   'Homicide',
#   '0',
#   'M',
#   '20',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['952',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '36',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['953',
#   '2012',
#   '11',
#   'Suicide',
#   '0',
#   'M',
#   '53',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['954', '2012', '12', 'Suicide', '0', 'M', '15', 'White', '100', 'Home', '1'],
#  ['955',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '50',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['956',
#   '2012',
#   '12',
#   'Suicide',
#   '0',
#   'F',
#   '33',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['957',
#   '2012',
#   '10',
#   'Suicide',
#   '0',
#   'M',
#   '25',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['958',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '54',
#   'Black',
#   '100',
#   'Home',
#   '3'],
#  ['959',
#   '2012',
#   '04',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['960',
#   '2012',
#   '05',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['961', '2012', '11', 'Suicide', '0', 'M', '72', 'White', '100', 'Home', '1'],
#  ['962',
#   '2012',
#   '12',
#   'Homicide',
#   '0',
#   'M',
#   '39',
#   'Black',
#   '100',
#   'Trade/service area',
#   '1'],
#  ['963',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '22',
#   'Black',
#   '100',
#   'Home',
#   '2'],
#  ['964', '2012', '01', 'Suicide', '0', 'M', '47', 'White', '100', 'Home', '3'],
#  ['965',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'F',
#   '24',
#   'White',
#   '100',
#   'Home',
#   '2'],
#  ['966',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '19',
#   'White',
#   '100',
#   'Other specified',
#   '1'],
#  ['967', '2012', '01', 'Suicide', '0', 'M', '61', 'White', '100', 'Home', '2'],
#  ['968', '2012', '01', 'Suicide', '0', 'M', '77', 'White', '100', 'Home', '3'],
#  ['969', '2012', '01', 'Suicide', '0', 'F', '34', 'White', '100', 'Home', '3'],
#  ['970', '2012', '01', 'Suicide', '0', 'F', '54', 'White', '100', 'Home', '1'],
#  ['971', '2012', '01', 'Suicide', '0', 'M', '75', 'White', '100', 'Home', '4'],
#  ['972', '2012', '01', 'Suicide', '0', 'F', '40', 'White', '100', 'Home', '2'],
#  ['973',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '36',
#   'White',
#   '100',
#   'Street',
#   '2'],
#  ['974',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'F',
#   '39',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['975', '2012', '01', 'Suicide', '0', 'M', '20', 'White', '100', 'Home', '1'],
#  ['976',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '28',
#   'White',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['977', '2012', '01', 'Suicide', '0', 'M', '20', 'Black', '100', 'Home', '1'],
#  ['978',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '78',
#   'White',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['979',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Trade/service area',
#   '2'],
#  ['980', '2012', '01', 'Suicide', '0', 'M', '58', 'White', '100', 'Home', '2'],
#  ['981', '2012', '01', 'Suicide', '0', 'M', '59', 'White', '100', 'Home', '4'],
#  ['982',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '73',
#   'White',
#   '100',
#   'Other specified',
#   '1'],
#  ['983', '2012', '01', 'Suicide', '0', 'M', '57', 'White', '100', 'Home', '1'],
#  ['984',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '28',
#   'Black',
#   '100',
#   'Other unspecified',
#   '2'],
#  ['985',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'F',
#   '16',
#   'White',
#   '100',
#   'Home',
#   '1'],
#  ['986',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '31',
#   'Black',
#   '100',
#   'Home',
#   '1'],
#  ['987', '2012', '01', 'Suicide', '0', 'M', '71', 'White', '100', 'Home', '2'],
#  ['988', '2012', '01', 'Suicide', '0', 'M', '42', 'White', '100', 'Home', '1'],
#  ['989',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '32',
#   'Black',
#   '100',
#   'Street',
#   '2'],
#  ['990', '2012', '01', 'Suicide', '0', 'M', '48', 'White', '100', 'Home', '2'],
#  ['991', '2012', '01', 'Suicide', '0', 'M', '82', 'White', '100', 'Home', '3'],
#  ['992', '2012', '01', 'Suicide', '0', 'M', '56', 'White', '100', 'Home', '1'],
#  ['993',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '41',
#   'White',
#   '100',
#   'Other specified',
#   '2'],
#  ['994', '2012', '01', 'Suicide', '0', 'M', '37', 'White', '100', 'Home', '2'],
#  ['995', '2012', '01', 'Suicide', '0', 'M', '53', 'White', '100', 'Home', '2'],
#  ['996', '2012', '01', 'Suicide', '0', 'M', '32', 'White', '100', 'Home', '2'],
#  ['997',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '24',
#   'White',
#   '100',
#   'Street',
#   '1'],
#  ['998',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '38',
#   'Black',
#   '100',
#   'Other specified',
#   '2'],
#  ['999',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'Native American/Native Alaskan',
#   '100',
#   'Home',
#   '4'],
#  ['1000',
#   '2012',
#   '01',
#   'Homicide',
#   '0',
#   'M',
#   '51',
#   'White',
#   '100',
#   'Home',
#   '4'],
#  ...]

# %%
data[0:5]
# Out:
# [['1',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '4'],
#  ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'],
#  ['3',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'],
#  ['5',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '31',
#   'White',
#   '100',
#   'Other specified',
#   '2']]

# %%
year_counts = {}
for row in data:
    years = row[1]
    if years in year_counts:
        year_counts[years] = year_counts[years] + 1
    else:
        year_counts[years] = 1

print(year_counts)
# Out:
# {'2012': 33563, '2013': 33636, '2014': 33599}

# %%
import datetime

dates = [datetime.datetime(year = int(row[1]),month=int(row[2]),day=1) for row in data]
dates[0:5]
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0)]

# %%
date_counts = {}

for row in dates:
    if row in date_counts:
        date_counts[row] += 1
    else:
        date_counts[row] = 1
date_counts
# Out:
# {datetime.datetime(2012, 1, 1, 0, 0): 2758,
#  datetime.datetime(2012, 2, 1, 0, 0): 2357,
#  datetime.datetime(2012, 3, 1, 0, 0): 2743,
#  datetime.datetime(2012, 4, 1, 0, 0): 2795,
#  datetime.datetime(2012, 5, 1, 0, 0): 2999,
#  datetime.datetime(2012, 6, 1, 0, 0): 2826,
#  datetime.datetime(2012, 7, 1, 0, 0): 3026,
#  datetime.datetime(2012, 8, 1, 0, 0): 2954,
#  datetime.datetime(2012, 9, 1, 0, 0): 2852,
#  datetime.datetime(2012, 10, 1, 0, 0): 2733,
#  datetime.datetime(2012, 11, 1, 0, 0): 2729,
#  datetime.datetime(2012, 12, 1, 0, 0): 2791,
#  datetime.datetime(2013, 1, 1, 0, 0): 2864,
#  datetime.datetime(2013, 2, 1, 0, 0): 2375,
#  datetime.datetime(2013, 3, 1, 0, 0): 2862,
#  datetime.datetime(2013, 4, 1, 0, 0): 2798,
#  datetime.datetime(2013, 5, 1, 0, 0): 2806,
#  datetime.datetime(2013, 6, 1, 0, 0): 2920,
#  datetime.datetime(2013, 7, 1, 0, 0): 3079,
#  datetime.datetime(2013, 8, 1, 0, 0): 2859,
#  datetime.datetime(2013, 9, 1, 0, 0): 2742,
#  datetime.datetime(2013, 10, 1, 0, 0): 2808,
#  datetime.datetime(2013, 11, 1, 0, 0): 2758,
#  datetime.datetime(2013, 12, 1, 0, 0): 2765,
#  datetime.datetime(2014, 1, 1, 0, 0): 2651,
#  datetime.datetime(2014, 2, 1, 0, 0): 2361,
#  datetime.datetime(2014, 3, 1, 0, 0): 2684,
#  datetime.datetime(2014, 4, 1, 0, 0): 2862,
#  datetime.datetime(2014, 5, 1, 0, 0): 2864,
#  datetime.datetime(2014, 6, 1, 0, 0): 2931,
#  datetime.datetime(2014, 7, 1, 0, 0): 2884,
#  datetime.datetime(2014, 8, 1, 0, 0): 2970,
#  datetime.datetime(2014, 9, 1, 0, 0): 2914,
#  datetime.datetime(2014, 10, 1, 0, 0): 2865,
#  datetime.datetime(2014, 11, 1, 0, 0): 2756,
#  datetime.datetime(2014, 12, 1, 0, 0): 2857}

# %%
sex_counts = {}

for row in data:
    sex = row[5]
    if sex in sex_counts:
        sex_counts[sex] += 1
    else:
        sex_counts[sex] = 1
        
sex_counts
# Out:
# {'F': 14449, 'M': 86349}

# %%
race_counts = {}

for row in data:
    race = row[7]
    if race in race_counts:
        race_counts[race] += 1
    else:
        race_counts[race] = 1

race_counts
# Out:
# {'Asian/Pacific Islander': 1326,
#  'Black': 23296,
#  'Hispanic': 9022,
#  'Native American/Native Alaskan': 917,
#  'White': 66237}

# %% [markdown]
# Gun deaths where women were the victim are far fewer in number than those where a man was the victim.  Female deaths amount to 16% of the male figure.
#
# African-American deaths are half that of deaths of white americans.
#
# Gun deaths are remarkably stable over a number of years.  It is difficult to extract whether this is because detection rates have remained broadly the same, or whether gun deaths have remained at a constant rate, or whether one of these variables is counterbalancing the other.
#
# Further things to look into would be:
#
# - whether rates of gun deaths are in proportion to the population
# - whether suicide rates are higher among certain populations
# - what accounts for the higher figure among white americans

# %%
intent_counts = {}

for row in data:
    intent = row[3]
    race = row[7]
    if intent in intent_counts:
        intent_counts[intent] += 1
    else:
        intent_counts[intent] = 1

print(intent_counts)
# Out:
# {'Suicide': 63175, 'Undetermined': 807, 'Accidental': 1639, 'Homicide': 35176, 'NA': 1}

# %%
g = open("census.csv", "r")
csvreader = csv.reader(g)
census = list(csvreader)
census
# Out:
# [['Id',
#   'Year',
#   'Id',
#   'Sex',
#   'Id',
#   'Hispanic Origin',
#   'Id',
#   'Id2',
#   'Geography',
#   'Total',
#   'Race Alone - White',
#   'Race Alone - Hispanic',
#   'Race Alone - Black or African American',
#   'Race Alone - American Indian and Alaska Native',
#   'Race Alone - Asian',
#   'Race Alone - Native Hawaiian and Other Pacific Islander',
#   'Two or More Races'],
#  ['cen42010',
#   'April 1, 2010 Census',
#   'totsex',
#   'Both Sexes',
#   'tothisp',
#   'Total',
#   '0100000US',
#   '',
#   'United States',
#   '308745538',
#   '197318956',
#   '44618105',
#   '40250635',
#   '3739506',
#   '15159516',
#   '674625',
#   '6984195']]

# %% [markdown]
# In order to get from the raw counts of gun deaths by race to a rate of gun deaths per 100000 people in each race, we'll need to divide the total number of gun deaths by the population of each race. From the census dataset, we know that the number of people in the White racial category is 197318956. We'd divide 66237 by 197318956:
#
# This gives us the percentage chance that a given person in the White census race category would have been killed by a gun in the US from 2012 to 2014. If you do this computation, you'll see that the rate is a very small number, 0.0003356849303419181. It's for this reason that it's typical to express crime statistics as the "rate per 100000". This tells you the number of people in a given group out of every 100000 that were killed by guns in the US. To get this, we just multiply by 100000:
#
#
# rate_per_hundredk = 0.0003356849303419181 * 100000
# This gives us 33.56, which we can interpret as "33.56 out of every 100000 people in the White census race category in the US were killed by guns between 2012 and 2014".
#
# We'll need to calculate these same rates for each racial category. The only stumbling block is that the racial categories are named slightly differently in census and in data. We'll need to manually construct a dictionary that allows us to map between them, and perform the division.
#
# Here's a list of the race name in data, and the corresponding race name in census:
#
# - Pacific Islander -- Race Alone - Asian plus Race Alone - Native Hawaiian and Other Pacific Islander.
# - Black -- Race Alone - Black or African American.
# - Hispanic -- Race Alone - Hispanic
# - Native American/Native Alaskan -- Race Alone - American Indian and - Alaska Native
# - White -- Race Alone - White
#
# We'll need to create a dictionary that has each race name from data as a key, and has the population count for the races from census as the values.

# %%
mapping = {'Asian/Pacific Islander': 15834141, 'Black': 40250635,'Hispanic': 44618105,
  'Native American/Native Alaskan': 3739506, 'White': 197318956}

race_per_hundredk = {}

for keys, values in race_counts.items():
    race_per_hundredk[keys] = (values/mapping[keys]) * 100000

race_per_hundredk
# Out:
# {'Asian/Pacific Islander': 8.374309664161762,
#  'Black': 57.8773477735196,
#  'Hispanic': 20.220491210910907,
#  'Native American/Native Alaskan': 24.521955573811088,
#  'White': 33.56849303419181}

# %% [markdown]
# ### Race and Likelihood of Gun Death
#
# We can filter our results, and restrict them to the Homicide intent. This will tell us what the gun-related murder rate per 100000 people in each racial category is. In order to do this, we'll need to redo our work in generating race_counts, but only count rows where the intent was Homicide.
#
# We can do this by first extracting the intent column, then using the enumerate() function to loop through each index and value in the race column. If the value in the same position in intents is Homicide, we'll count the value in the race column.
#
# Finally, we'll use the mapping dictionary to convert from raw counts to rates.

# %%
homicide_race_counts = {}
intents = [row[3] for row in data]
races = [row[7] for row in data]
for i,race in enumerate(races):
    if race not in homicide_race_counts:
        homicide_race_counts[race] = 0
    if intents[i] == "Homicide":
        homicide_race_counts[race] += 1
        
race_per_hundredk = {}
for keys,values in homicide_race_counts.items():
    race_per_hundredk[keys] = values/mapping[keys] * 100000
    
race_per_hundredk
# Out:
# {'Asian/Pacific Islander': 3.530346230970155,
#  'Black': 48.471284987180944,
#  'Hispanic': 12.627161104219914,
#  'Native American/Native Alaskan': 8.717729026240365,
#  'White': 4.6356417981453335}

# %% [markdown]
# Certainly you are comparatively more likely to die from a gunshot wound as a black american than as any other race.  Despite the high prevalence of white gunshot deaths, the number that are due to homicides is comparatively slight, suggesting that other factors account for more gun deaths among the white population.
#
# Large, but not as pronounced, is the rate of hispanic gun deaths from Homicides. So what can account for the fact that white gun deaths are quite high overall per 100000.
#
# What about Suicides? Let's look at the data in a similar way to that which we did for homicides.

# %%
intents = [row[3] for row in data]
suicide_race_counts = {}
for i,race in enumerate(races):
    if race not in suicide_race_counts:
        suicide_race_counts[race] = 0
    if intents[i] == "Suicide":
        suicide_race_counts[race] += 1

suicide_per_hundredk = {}
for k,v in suicide_race_counts.items():
    suicide_per_hundredk[k] = (v / mapping[k]) * 100000

suicide_per_hundredk
# Out:
# {'Asian/Pacific Islander': 4.705023152187416,
#  'Black': 8.278130270491385,
#  'Hispanic': 7.106980451097149,
#  'Native American/Native Alaskan': 14.841532544673013,
#  'White': 28.06217969245692}

# %% [markdown]
# ### Undetermined Deaths
#
# What about Undetermined deaths? They are relatively small in number.  Oddly, hispanic gun deaths by Undetermined cause appear to be fewer per hundred thousand than other races. Would be interesting to find out why that is.

# %%
intents = [row[3] for row in data]
undetermined_race_counts = {}
for i,race in enumerate(races):
    if race not in undetermined_race_counts:
        undetermined_race_counts[race] = 0
    if intents[i] == "Undetermined":
        undetermined_race_counts[race] += 1

undetermined_per_hundredk = {}
for k,v in undetermined_race_counts.items():
    undetermined_per_hundredk[k] = (v / mapping[k]) * 100000

undetermined_per_hundredk
# Out:
# {'Asian/Pacific Islander': 0.0631546731837237,
#  'Black': 0.3130385396404305,
#  'Hispanic': 0.16136947098044616,
#  'Native American/Native Alaskan': 0.3743810011268868,
#  'White': 0.2964743032595409}

# %% [markdown]
# ### Education
#
# So what role does education play? First let's do a rough cut of counts for different levels of attainment. Handily, the education column is already converted to an integer.

# %%
education_counts = {}
education = [row[10] for row in data]
races = [row[7] for row in data]
for i,ed in enumerate(education):
    if ed not in education_counts:
        education_counts[ed] = 0
    if ed in education_counts:
        education_counts[ed] += 1

education_counts
# Out:
# {'1': 21823, '2': 42927, '3': 21680, '4': 12946, '5': 1369, 'NA': 53}

# %% [markdown]
# So we see here that educational attainment appears to have a marked effect on the likelihood of a gun death, but the relationship is not directly inversely proportional.  For example, we could jump to the ludicrous assumption that those who graduated from high school are a menace to society.  We'd need to compare the rates with educational attainment in the wider population in order to understand the precise relationship, if any, between gun deaths and educational attainment.  For example, we cannot isolate whether college education is responsible for the lower incidence of gun deaths at that level of educational attainment, since there might naturally be a lower incidence of college education in the population.
#
# One way that gives us further insight is to perform

# %% [markdown]
# ### Geography
#
# What about where people died? It does seem from a simple count that home is among the most common places for a gun death to occur.

# %%
place_counts = {}
places = [row[9] for row in data]
for i,place in enumerate(places):
    if place not in place_counts:
        place_counts[place] = 0
    if place in place_counts:
        place_counts[place] += 1
        
place_counts
# Out:
# {'Farm': 470,
#  'Home': 60486,
#  'Industrial/construction': 248,
#  'NA': 1384,
#  'Other specified': 13751,
#  'Other unspecified': 8867,
#  'Residential institution': 203,
#  'School/instiution': 671,
#  'Sports': 128,
#  'Street': 11151,
#  'Trade/service area': 3439}

# %%
month_counts = {}
months = [row[3] for row in data]
for i,month in enumerate(months):
    if month == :
        month_counts[month] = month_counts[month] + 1
    else:
        month_counts[month] = 1

month_counts
# Out:
#   File "<ipython-input-17-636d485c0d1c>", line 5
#     if month == :
#                 ^
# SyntaxError: invalid syntax

# %%
race_by_death = {}
for rows in data:
    education = row[10]
    races = row[7]
    intents = row[3]
    if row[10] == (3 or 4 or 5):
        race_by_death[intents] += 1
    else:
        race_by_death[intents] = 1
        
race_by_death
# Out:
# {'Homicide': 1}
